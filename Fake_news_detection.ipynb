# %%
import pandas as pd
import numpy as np
import re
import string

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\rekha'

# %%
import shutil

shutil.copy(
    r"C:\Users\rekha\OneDrive\Fake.csv",
    r"C:\Users\rekha\Fake.csv"
)

shutil.copy(
    r"C:\Users\rekha\OneDrive\True.csv",
    r"C:\Users\rekha\True.csv"
)

print("Done")
# Out:
# Done

# %%
import pandas as pd

data_fake = pd.read_csv("Fake.csv")
data_true = pd.read_csv("True.csv")

print(data_fake.head())
print(data_true.head())
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
data_fake["class"] = 0
data_true["class"] = 1

data = pd.concat([data_fake, data_true])

data = data.sample(frac=1)

data.reset_index(inplace=True)

data.drop(["index"], axis=1, inplace=True)

print(data.shape)
# Out:
# (44898, 5)

# %%
import re
import string

def clean_text(text):

    text = text.lower()

    text = re.sub(r'\[.*?\]', '', text)

    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    text = re.sub(r'<.*?>+', '', text)

    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)

    text = re.sub(r'\n', '', text)

    text = re.sub(r'\w*\d\w*', '', text)

    return text

# %%
data_fake["class"] = 0
data_true["class"] = 1

data = pd.concat([data_fake, data_true])

data = data.sample(frac=1)

data.reset_index(inplace=True)

data.drop(["index"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_fake["class"] = 0
#       2 data_true["class"] = 1
#       4 data = pd.concat([data_fake, data_true])
#
# NameError: name 'data_fake' is not defined

# %%
import pandas as pd

data_fake = pd.read_csv("Fake.csv")
data_true = pd.read_csv("True.csv")

# %%
data_fake["class"] = 0
data_true["class"] = 1

data = pd.concat([data_fake, data_true])

data = data.sample(frac=1)

data.reset_index(inplace=True)

data.drop(["index"], axis=1, inplace=True)

# %%
import re
import string

def clean_text(text):

    text = text.lower()

    text = re.sub(r'\[.*?\]', '', text)

    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    text = re.sub(r'<.*?>+', '', text)

    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)

    text = re.sub(r'\n', '', text)

    text = re.sub(r'\w*\d\w*', '', text)

    return text

# %%
data["text"] = data["text"].apply(clean_text)

print(data["text"].head())
# Out:
# 0    two muslims spit on a dutch reporter and then ...
# 1    simi valley california reuters  often fiercely...
# 2    we d like to offer a special word of  thanks  ...
# 3    government waste and abuse runs rampant but th...
# 4    washington reuters  the us supreme court on tu...
# Name: text, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

x = data["text"]
y = data["class"]

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.25,
    random_state=42
)

vectorization = TfidfVectorizer()

xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

print("Done")
# Out:
# Done

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()

model.fit(xv_train, y_train)

pred = model.predict(xv_test)

accuracy = accuracy_score(y_test, pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9862806236080178

# %%
def output_label(n):

    if n == 0:
        return "Fake News"

    else:
        return "True News"


def manual_testing(news):

    testing_news = {"text": [news]}

    new_def_test = pd.DataFrame(testing_news)

    new_def_test["text"] = new_def_test["text"].apply(clean_text)

    new_x_test = vectorization.transform(new_def_test["text"])

    pred = model.predict(new_x_test)

    return output_label(pred[0])

# %%
news = input("Enter news: ")

print(manual_testing(news))
# Out:
# Enter news:  India won the match today from England
# Fake News

# %%
news = input("Enter news: ")

print(manual_testing(news))
# Out:
# Enter news:  is Trump dead
# Fake News

# %%
while True:
    news = input("Enter news: ")

    if news == "exit":
        break

    print(manual_testing(news))
# Out:
# Enter news:  is gold rate below than 50000
# Fake News
